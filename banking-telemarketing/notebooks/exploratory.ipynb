# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\Dell\Documents\my_linux\repos\bank-telemarketing\banking-telemarketing\data\processed\cleaned.csv")
df.shape
# Out:
# (45211, 13)

# %%
df.head(3)
# Out:
#    age  marital  education default  balance housing loan  day month  duration  \
# 0   58  married   tertiary      no     2143     yes   no    5   may       261
# 1   44   single  secondary      no       29     yes   no    5   may       151
# 2   33  married  secondary      no        2     yes  yes    5   may        76
#
#    previous poutcome   y
# 0         0  unknown  no
# 1         0  unknown  no
# 2         0  unknown  no
